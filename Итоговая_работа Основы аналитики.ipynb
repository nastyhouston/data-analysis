# %% [markdown]
# # Итоговая работа по курсу «Основы аналитики и аналитическое мышление»

# %% [markdown]
# ## Задача: Разработать систему аналитики для учета и планирования отпусков.

# %% [markdown]
# ### Задание 1.
# Разработайте Google-форму, позволяющую планировать отпуск. Форма должна содержать следующие поля:
# * Страна
# * Город
# * Дата начала
# * Дата окончания
# * Планируемый бюджет
# Результаты должны сохраняться в Google-таблицу

# %% [markdown]
# Google-форма к Заданию 1
#
# https://docs.google.com/forms/d/e/1FAIpQLSd6AvNx55TtFU-5lx_UZBMIGJiF0s44wg90Q3AzJyqcYkHNBw/viewform

# %% [markdown]
# ### Задание 2.
# Добавьте в Google-таблицы столбцы для заполнения информации по фактической информации по отпуску. Столбцы должны содержать следующую информацию:
# * Стоимость билетов
# * Стоимость отеля
# * Траты на отдыхе
# * Общая оценка отпуска по шкале от 1 до 5
# * Столбец с итоговой стоимостью отпуска (сумма трех столбцов выше)
# * Отклонение итоговой стоимости от плана
# * Стоимость одного дня отпуска
# Последние 3 столбца должны вычисляться с помощью формул.
#
# Внесите данные по 10 и более отпускам за последние 3 года (данные могут быть вымышленные).
#
# Рассчитайте корреляцию между ценой отпуска за день и оценкой за отзыв.
# Постройте точечный график с этими показателями
#
# Проверьте статистическую гипотезу, что вы хорошо планируете отпуска: среднее отклонение планируемых трат от реальных равно 0

# %% [markdown]
# Таблица к заданию 2
# https://docs.google.com/spreadsheets/d/15O_m3o_CbnT4EKyZIlolJy-c6SezfBh-JD9qB39bduM/edit?usp=sharing

# %% [markdown]
# ### Задание 3.
# При помощи Python и SQL найдите, как называются ваши города в таблице City базы данных World-db (строка подключения  - postgresql://netology:NetoSQL2019@84.201.177.166:19001/world-db)
#
# Создайте соответствующий справочник на отдельном листе Google-таблиц
#
# Добавьте колонку с английским названием города при помощи функции VLOOKUP (ВПР)

# %%
import pandas as pd

# %%
df = pd.read_sql(
"""
select
 *
from
 City
""",
"postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db"
)
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4079 entries, 0 to 4078
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            4079 non-null   int64
#  1   name          4079 non-null   object
#  2   country_code  4079 non-null   object
#  3   district      4079 non-null   object
#  4   population    4079 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 159.5+ KB

# %%
df.head()
# Out:
#    id            name country_code       district  population
# 0   1           Kabul          AFG          Kabol     1780000
# 1   2        Qandahar          AFG       Qandahar      237500
# 2   3           Herat          AFG          Herat      186800
# 3   4  Mazar-e-Sharif          AFG          Balkh      127800
# 4   5       Amsterdam          NLD  Noord-Holland      731200

# %%
df.to_excel('city.xls')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Таблица к заданию 3 (вкладка "Справочник городов)
#
#  https://docs.google.com/spreadsheets/d/15O_m3o_CbnT4EKyZIlolJy-c6SezfBh-JD9qB39bduM/edit?usp=sharing

# %% [markdown]
# ### Задание 4.
# Скачайте данные в CSV и откройте их в Python
#
# При помощи SQL и Python получите датафрейм с названием города и его населением из таблицы City
#
# При помощи Python соедините данные из выгруженного CSV файла и таблицы с населением города.
#
# Сгруппируйте итоговый датафрейм по странам и рассчитайте среднюю численность населения в странах, где вы отдыхали

# %%
pd.read_csv('vacation.csv')
# Out:
#         Отметка времени      Страна         Город RU               Город ENG  \
# 0   19.06.2022 16:59:59      Россия           Москва                  Moscow
# 1   19.06.2022 17:09:41     Армения           Ереван                 Yerevan
# 2   19.06.2022 22:51:06    Норвегия           Берген                  Bergen
# 3   19.06.2022 22:54:53      Латвия             Рига                    Riga
# 4   19.06.2022 22:57:31       Чехия            Прага                   Praha
# 5   19.06.2022 23:06:37       Индия          Джайпур                  Jaipur
# 6   19.06.2022 23:11:14      Грузия           Батуми                  Batumi
# 7   19.06.2022 23:14:50      Япония            Киото                   Kioto
# 8   19.06.2022 23:17:25  Черногория            Будва              нет данных
# 9   19.06.2022 23:21:42   Финляндия        Хельсинки  Helsinki [Helsingfors]
# 10  19.06.2022 23:25:11       Китай           Шанхай                Shanghai
# ...

# %%
df_vacation = pd.read_csv('vacation.csv')

# %%
df_population = df.iloc[:, [1, 4]]
df_population.head()
# Out:
#              name  population
# 0           Kabul     1780000
# 1        Qandahar      237500
# 2           Herat      186800
# 3  Mazar-e-Sharif      127800
# 4       Amsterdam      731200

# %%
df_general = df_vacation.merge(df_population,left_on='Город ENG',right_on='name', how='left')
df_general.head()
# Out:
#        Отметка времени    Страна Город RU Город ENG Дата начала  \
# 0  19.06.2022 16:59:59    Россия   Москва    Moscow  02.01.2019
# 1  19.06.2022 17:09:41   Армения   Ереван   Yerevan  29.04.2019
# 2  19.06.2022 22:51:06  Норвегия   Берген    Bergen  19.07.2019
# 3  19.06.2022 22:54:53    Латвия     Рига      Riga  23.09.2019
# 4  19.06.2022 22:57:31     Чехия    Прага     Praha  23.12.2019
#
#   Дата окончания  Количество дней отпуска Планируемый бюджет  \
# 0     06.01.2019                        4           60000,00
# 1     05.05.2019                        6           70000,00
# 2     25.07.2019                        6          120000,00
# 3     29.09.2019                        6           50000,00
# 4     27.12.2019                        4           30000,00
#
#   Стоимость билетов Стоимость отеля Траты на отдыхе  Общая оценка отпуска  \
# 0          10000,00         8000,00        40000,00                     4
# ...

# %%
df_group = df_general.groupby('Страна')
df_group.head()
# Out:
#         Отметка времени      Страна         Город RU               Город ENG  \
# 0   19.06.2022 16:59:59      Россия           Москва                  Moscow
# 1   19.06.2022 17:09:41     Армения           Ереван                 Yerevan
# 2   19.06.2022 22:51:06    Норвегия           Берген                  Bergen
# 3   19.06.2022 22:54:53      Латвия             Рига                    Riga
# 4   19.06.2022 22:57:31       Чехия            Прага                   Praha
# 5   19.06.2022 23:06:37       Индия          Джайпур                  Jaipur
# 6   19.06.2022 23:11:14      Грузия           Батуми                  Batumi
# 7   19.06.2022 23:14:50      Япония            Киото                   Kioto
# 8   19.06.2022 23:17:25  Черногория            Будва              нет данных
# 9   19.06.2022 23:21:42   Финляндия        Хельсинки  Helsinki [Helsingfors]
# 10  19.06.2022 23:25:11       Китай           Шанхай                Shanghai
# ...

# %%
df_group['population'].mean()
# Out:
# Страна
# Армения       1248700.0
# Германия      1194560.0
# Грузия         137700.0
# Индия         1458483.0
# Китай         9696300.0
# Куба                NaN
# Латвия         764328.0
# Норвегия       230948.0
# Россия        6541600.0
# Турция              NaN
# Финляндия      555474.0
# Черногория          NaN
# Чехия         1181126.0
# Япония        1461974.0
# Name: population, dtype: float64

# %% [markdown]
# Работа выполнена
